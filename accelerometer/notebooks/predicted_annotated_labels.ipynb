# %%
import os
import pandas as pd
import csv
import numpy as np
import time

from datetime import datetime
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

predicted_data_path = "/home/aayush/accelerometer/accprocess/results"
predicted_data_path_custom_model = "/home/aayush/accelerometer/accProcess-custom/results/time-series"
annotated_data_path = "/home/yacine/accel/capture24/participants/"

# %%
def get_files(data_path, predicted_files=False, annotated_files=False) -> None:
    total_csv_zipped = []
    for path, dirnames, filenames in os.walk(data_path):
        for file in filenames:
            if file.endswith(".csv.gz") and predicted_files:
                # paths contains the base directory for that file.
                # dirnames contains other directories within this folder.
                # filenames contains the list of filenames within path.
                total_csv_zipped.append(os.path.join(path, file))
                
            if file.endswith(".csv") and annotated_files and file[0]!='c': #ignore the capture24 file
                # paths contains the base directory for that file.
                # dirnames contains other directories within this folder.
                # filenames contains the list of filenames within path.
                total_csv_zipped.append(os.path.join(path, file))
                
    return sorted(total_csv_zipped)

# %%
def parse_datetime(dt_string):
    clean_datetime_str = dt_string.split('[')[0].strip()
    dt_object = pd.to_datetime(clean_datetime_str)
    return dt_object


def parse_datetime_df_time(dt_string):
    clean_datetime_str = dt_string.split('[')[0].strip()
    clean_datetime_str = clean_datetime_str.split('+')[0].strip()
    dt_object = pd.to_datetime(clean_datetime_str)
    return dt_object

# %%
predicted_data_files = get_files(data_path=predicted_data_path_custom_model, predicted_files=True)
annotated_data_files = get_files(data_path=annotated_data_path, annotated_files=True)
assert len(predicted_data_files) == len(annotated_data_files), "Number of predicted and annotated data files should be the same."

# %%
labels_dict_location = "/home/aayush/accelerometer/accprocess/anno-label.csv"

def create_labels_dict():
    labels_dict = {}
    with open(labels_dict_location, "r") as annotation_dict:
        reader = csv.DictReader(annotation_dict)
        for row in reader:
            if labels_dict.get(row['annotation']) is None:
                labels_dict[row['annotation']] = [row['label:Walmsley2020']]
            else:
                labels_dict[row['annotation']].append(row['label:Walmsley2020'])
    return labels_dict

labels_dict = create_labels_dict()

# %%
def process_annotated_data(annotated_data_file):
    annotated_data = pd.read_csv(annotated_data_file)
    # Take the timestamp after every thirty seconds
    actual_labels = annotated_data[["annotation", "time"]][0::3000]
    
    # Convert to datetime object
    actual_time = actual_labels["time"].apply(parse_datetime)
    actual_labels["time"] = actual_time

    # replace the annotated labels with the same format of strings as predicted labels using mapping from labels_dict
    flat_dict = {k: v[0] for k, v in labels_dict.items()}
    
    actual_labels['annotation'].replace(flat_dict, inplace=True)    
    
    return actual_labels

# %%
all_epoch_dfs_predicted = []
all_epoch_dfs_annotated = []
for predicted_data_file, annotated_data_file in zip(predicted_data_files, annotated_data_files):
    annotated_df = process_annotated_data(annotated_data_file)
    predicted_df = pd.read_csv(predicted_data_file)
    
    # Convert to datetime object
    df_cleaned_time = predicted_df['time'].apply(parse_datetime_df_time)
    predicted_df['time'] = df_cleaned_time
    
    # retrieve only the activities headers
    activities = predicted_df[predicted_df.columns.values.tolist()[2:6]]
    
    # whichever activity is depicted by 1, use it as the predicted activity
    out = activities[activities==1].idxmax(axis=1)
    predicted_df["activity_predicted"] = out
    
    annotated_df["participant"] = float(annotated_data_file.split("/")[-1].split(".")[0][1:])
    predicted_df_subset = predicted_df[['time', 'MET', 'activity_predicted', 'CpSB', 'CpLPA', 'CpMPA', 'CpVPA', 'CpMVPA']]
    predicted_df_subset["participant"] = float(predicted_data_file.split("/")[-1].split("-")[0][1:])
    
    # annotated_df = pd.merge_asof(annotated_df, predicted_df_subset, on="time")
    # annotated_df["MET"] = predicted_df["MET"]
    # annotated_df["activity_predicted"] = predicted_df["activity_predicted"]
    print(f"Done for: {annotated_data_file}, {predicted_data_file}.")
    all_epoch_dfs_annotated.append(annotated_df)
    all_epoch_dfs_predicted.append(predicted_df_subset)
# Out:
# /tmp/ipykernel_274774/2474945704.py:4: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   annotated_df = process_annotated_data(annotated_data_file)
# /tmp/ipykernel_274774/2474945704.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predicted_df_subset["participant"] = float(predicted_data_file.split("/")[-1].split("-")[0][1:])
# Done for: /home/yacine/accel/capture24/participants/P001.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P001-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P002.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P002-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P003.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P003-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P004.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P004-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P005.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P005-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P006.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P006-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P007.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P007-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P008.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P008-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P009.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P009-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P010.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P010-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P011.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P011-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P012.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P012-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P013.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P013-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P014.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P014-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P015.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P015-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P016.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P016-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P017.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P017-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P018.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P018-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P019.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P019-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P020.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P020-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P021.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P021-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P022.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P022-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P023.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P023-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P024.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P024-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P025.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P025-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P026.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P026-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P027.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P027-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P028.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P028-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P029.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P029-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P030.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P030-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P031.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P031-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P032.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P032-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P033.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P033-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P034.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P034-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P035.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P035-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P036.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P036-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P037.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P037-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P038.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P038-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P039.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P039-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P040.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P040-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P041.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P041-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P042.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P042-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P043.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P043-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P044.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P044-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P045.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P045-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P046.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P046-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P047.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P047-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P048.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P048-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P049.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P049-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P050.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P050-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P051.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P051-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P052.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P052-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P053.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P053-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P054.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P054-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P055.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P055-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P056.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P056-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P057.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P057-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P058.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P058-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P059.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P059-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P060.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P060-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P061.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P061-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P062.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P062-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P063.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P063-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P064.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P064-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P065.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P065-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P066.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P066-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P067.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P067-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P068.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P068-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P069.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P069-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P070.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P070-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P071.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P071-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P072.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P072-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P073.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P073-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P074.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P074-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P075.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P075-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P076.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P076-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P077.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P077-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P078.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P078-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P079.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P079-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P080.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P080-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P081.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P081-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P082.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P082-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P083.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P083-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P084.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P084-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P085.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P085-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P086.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P086-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P087.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P087-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P088.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P088-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P089.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P089-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P090.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P090-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P091.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P091-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P092.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P092-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P093.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P093-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P094.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P094-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P095.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P095-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P096.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P096-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P097.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P097-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P098.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P098-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P099.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P099-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P100.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P100-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P101.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P101-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P102.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P102-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P103.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P103-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P104.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P104-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P105.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P105-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P106.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P106-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P107.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P107-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P108.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P108-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P109.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P109-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P110.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P110-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P111.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P111-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P112.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P112-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P113.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P113-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P114.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P114-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P115.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P115-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P116.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P116-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P117.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P117-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P118.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P118-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P119.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P119-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P120.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P120-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P121.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P121-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P122.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P122-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P123.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P123-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P124.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P124-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P125.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P125-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P126.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P126-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P127.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P127-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P128.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P128-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P129.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P129-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P130.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P130-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P131.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P131-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P132.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P132-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P133.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P133-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P134.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P134-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P135.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P135-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P136.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P136-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P137.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P137-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P138.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P138-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P139.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P139-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P140.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P140-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P141.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P141-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P142.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P142-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P143.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P143-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P144.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P144-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P145.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P145-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P146.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P146-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P147.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P147-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P148.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P148-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P149.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P149-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P150.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P150-timeSeries.csv.gz.
# Done for: /home/yacine/accel/capture24/participants/P151.csv, /home/aayush/accelerometer/accProcess-custom/results/time-series/P151-timeSeries.csv.gz.

# %%
epochs_predicted = pd.concat(all_epoch_dfs_predicted)
epochs_annotated = pd.concat(all_epoch_dfs_annotated)

# %%
epochs_predicted.to_csv("/home/aayush/accelerometer/predicted_custom_all.csv", index=False)
epochs_annotated.to_csv("/home/aayush/accelerometer/annotated_custom_all.csv", index=False)
