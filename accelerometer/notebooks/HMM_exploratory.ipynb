# %%
import pandas as pd
df = pd.read_csv("/home/aayush/accelerometer/trainClassification_input.csv")
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
df.head()
# Out:
#    enmoTrunc   enmoAbs     xMean     yMean     zMean    xRange    yRange  \
# 0   0.001423  0.003816 -0.166901 -0.484580  0.857529  0.030880  0.031312
# 1   0.001348  0.003484 -0.178192 -0.483312  0.856078  0.108079  0.062623
# 2   0.003601  0.007880 -0.154394 -0.423471  0.863931  1.173425  0.438355
# 3   0.004124  0.007625  0.122261 -0.335273  0.924189  0.926388  0.313111
# 4   0.001921  0.002880  0.158215 -0.332628  0.930696  0.030880  0.031312
#
#      zRange      xStd      yStd      zStd     xyCov     xzCov     yzCov  \
# 0  0.031563  0.002064  0.003589  0.006802  0.000000  0.000001  0.000002
# 1  0.047344  0.012771  0.006186  0.006572  0.000001  0.000022  0.000005
# 2  0.599680  0.174307  0.117852  0.071822  0.010047  0.011291  0.003471
# 3  0.426089  0.134946  0.025022  0.036352 -0.000924  0.003560 -0.000113
# 4  0.031563  0.003275  0.006807  0.005259 -0.000000  0.000001  0.000004
#
#        mean        sd  coefvariation    median       min       max     25thp  \
# ...

# %%
len(df)
# Out:
# 462477

# %%
df['annotation'].unique()
# Out:
# array(['sleep', 'walking', 'vehicle', 'sit-stand', 'mixed', 'bicycling'],
#       dtype=object)

# %%
df['MET'].unique()
# Out:
# array([0.95      , 3.09      , 1.84      , 1.71134021, 3.54756098,
#        4.        ])

# %%
df
# Out:
#         enmoTrunc   enmoAbs     xMean     yMean     zMean    xRange    yRange  \
# 0        0.001423  0.003816 -0.166901 -0.484580  0.857529  0.030880  0.031312
# 1        0.001348  0.003484 -0.178192 -0.483312  0.856078  0.108079  0.062623
# 2        0.003601  0.007880 -0.154394 -0.423471  0.863931  1.173425  0.438355
# 3        0.004124  0.007625  0.122261 -0.335273  0.924189  0.926388  0.313111
# 4        0.001921  0.002880  0.158215 -0.332628  0.930696  0.030880  0.031312
# ...           ...       ...       ...       ...       ...       ...       ...
# 462472   0.005676  0.005677 -0.673620 -0.325168 -0.672207  0.016061  0.031951
# 462473   0.006095  0.006095 -0.673528 -0.325300 -0.672869  0.031749  0.031951
# 462474   0.006277  0.006277 -0.673516 -0.325243 -0.673177  0.031377  0.031862
# 462475   0.006433  0.006433 -0.673527 -0.325302 -0.673372  0.015689  0.031862
# 462476   0.006875  0.006905 -0.673563 -0.325355 -0.673915  0.062754  0.031862
#
# ...

# %%
df.head()
# Out:
#    enmoTrunc   enmoAbs     xMean     yMean     zMean    xRange    yRange  \
# 0   0.001423  0.003816 -0.166901 -0.484580  0.857529  0.030880  0.031312
# 1   0.001348  0.003484 -0.178192 -0.483312  0.856078  0.108079  0.062623
# 2   0.003601  0.007880 -0.154394 -0.423471  0.863931  1.173425  0.438355
# 3   0.004124  0.007625  0.122261 -0.335273  0.924189  0.926388  0.313111
# 4   0.001921  0.002880  0.158215 -0.332628  0.930696  0.030880  0.031312
#
#      zRange      xStd      yStd      zStd     xyCov     xzCov     yzCov  \
# 0  0.031563  0.002064  0.003589  0.006802  0.000000  0.000001  0.000002
# 1  0.047344  0.012771  0.006186  0.006572  0.000001  0.000022  0.000005
# 2  0.599680  0.174307  0.117852  0.071822  0.010047  0.011291  0.003471
# 3  0.426089  0.134946  0.025022  0.036352 -0.000924  0.003560 -0.000113
# 4  0.031563  0.003275  0.006807  0.005259 -0.000000  0.000001  0.000004
#
#        mean        sd  coefvariation    median       min       max     25thp  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462477 entries, 0 to 462476
# Data columns (total 73 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   enmoTrunc           462477 non-null  float64
#  1   enmoAbs             462477 non-null  float64
#  2   xMean               462477 non-null  float64
#  3   yMean               462477 non-null  float64
#  4   zMean               462477 non-null  float64
#  5   xRange              462477 non-null  float64
#  6   yRange              462477 non-null  float64
#  7   zRange              462477 non-null  float64
#  8   xStd                462477 non-null  float64
#  9   yStd                462477 non-null  float64
#  10  zStd                462477 non-null  float64
#  11  xyCov               462477 non-null  float64
#  12  xzCov               462477 non-null  float64
#  13  yzCov               462477 non-null  float64
#  14  mean                462477 non-null  float64
# ...

# %%
df.describe()
# Out:
#            enmoTrunc        enmoAbs          xMean          yMean  \
# count  462477.000000  462477.000000  462477.000000  462477.000000
# mean        0.032563       0.050073      -0.146670      -0.002244
# std         0.065180       0.083083       0.593670       0.444481
# min         0.000000       0.000100      -1.570179      -2.494136
# 25%         0.001947       0.004553      -0.660676      -0.317290
# 50%         0.008107       0.014651      -0.303059       0.009335
# 75%         0.036566       0.062178       0.403587       0.305267
# max         2.928140       2.935092       1.175902       1.522048
#
#                zMean         xRange         yRange         zRange  \
# count  462477.000000  462477.000000  462477.000000  462477.000000
# mean        0.169111       1.476349       1.254446       1.296943
# std         0.531887       2.022194       1.831998       1.778655
# min        -1.133037       0.000000       0.000000       0.000000
# ...

# %%
print(df.isnull().sum())
# Out:
# enmoTrunc      0
# enmoAbs        0
# xMean          0
# yMean          0
# zMean          0
#               ..
# rawSamples     0
# participant    0
# MET            0
# label          0
# annotation     0
# Length: 73, dtype: int64

# %%
pd.set_option('display.max_columns', 100)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation heatmap for a subset of features
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, fmt=".2f")  # Adjust as necessary
plt.show()

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 4.4 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# Pairplot for selected features to see pairwise relationships and distributions
sns.pairplot(df)  # Adjust the list as necessary
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Pairplot for selected features to see pairwise relationships and distributions
# ----> 2 sns.pairplot(df)  # Adjust the list as necessary
#       3 plt.show()
#
# File ~/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:2119, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117 # Set up the PairGrid
#    2118 grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119 grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                 hue_order=hue_order, palette=palette, corner=corner,
#    2121                 height=height, aspect=aspect, dropna=dropna, **grid_kws)
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

model.fit(df.iloc[:, :-4], df['label'])  # assuming 'target' is your dependent variable
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 8
#       5 model.fit(df.iloc[:, :-4], df['label'])  # assuming 'target' is your dependent variable
#       7 # Display feature importances
# ----> 8 feature_importances = pd.Series(model.feature_importances_, index=df.columns[:-1])
#       9 print(feature_importances.nlargest(20))  # Show the top 20 features
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:430, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     428     index = ibase.default_index(len(data))
#     429 elif is_list_like(data):
# --> 430     com.require_length_match(data, index)
#     432 # create/copy the manager
#     433 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/common.py:531, in require_length_match(data, index)
# ...

# %%
# Display feature importances
feature_importances = pd.Series(model.feature_importances_, index=df.columns[:-4])
print(feature_importances.nlargest(30))  # Show the top 20 features
# Out:
# yMean          0.026702
# yawg           0.025758
# xMean          0.025438
# rollg          0.025289
# pitchg         0.024271
# zMean          0.023990
# avgArmAngel    0.023806
# xRange         0.022176
# yRange         0.019376
# enmoTrunc      0.018329
# enmoAbs        0.017965
# zRange         0.017892
# skew           0.017785
# avgroll        0.017341
# avgyaw         0.017256
# avgpitch       0.017107
# yStd           0.016584
# corrxy         0.016455
# corryz         0.016443
# xStd           0.016417
# kurt           0.016380
# corrxz         0.016147
# sdyaw          0.016096
# zStd           0.016004
# sdpitch        0.015959
# totalPower     0.015668
# sdroll         0.015613
# MAD            0.015250
# autocorr       0.015029
# entropy        0.014939
# dtype: float64

# %%
df.shape
# Out:
# (462477, 73)
